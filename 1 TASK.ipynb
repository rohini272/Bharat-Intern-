# %% [markdown]
# # Stock Prediction Using LSTM
# # Task 1 - Rohini Ninawe

# %%
from IPython import display
display.Image("LSTM.png")

# %%
#importing libraries to be used
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') 
from sklearn.preprocessing import MinMaxScaler 
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectiona
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 10
#       8 warnings.filterwarnings('ignore')
#       9 from sklearn.preprocessing import MinMaxScaler
# ---> 10 from keras.models import Sequential
#      11 from keras.layers import Dense, Dropout, LSTM, Bidirectiona
#
# ModuleNotFoundError: No module named 'keras'

# %% [markdown]
# # Read csv file (NETFLIX stock price year 2018- 2022)

# %%
# data_importing
df = pd.read_csv("NFLX.csv")
# fetching first 10 rows of dataset
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400

# %% [markdown]
# # Data Exploration & Cleaning

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
df.shape
# Out:
# (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
# check for non-null values
df.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
#checking for the null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Check for required columns
df = df[['Date','Open','Close']] 

# converting object dtype of date column to datetime dtype

df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))

# %%
df.set_index('Date',drop=True,inplace=True) 
df.head(10)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001
# 2018-02-12  252.139999  257.950012
# 2018-02-13  257.290009  258.269989
# 2018-02-14  260.470001  266.000000
# 2018-02-15  270.029999  280.269989
# 2018-02-16  278.730011  278.519989

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'Close'}>]], dtype=object)

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='blue')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='green')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# # Pre Processing of the Data

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
df.tail(10)
# Out:
#                 Open     Close
# Date
# 2022-01-24  0.327182  0.334790
# 2022-01-25  0.316777  0.289509
# 2022-01-26  0.314879  0.274830
# 2022-01-27  0.323146  0.333807
# 2022-01-28  0.333399  0.328695
# 2022-01-31  0.366577  0.422140
# 2022-02-01  0.434178  0.487648
# 2022-02-02  0.467531  0.427251
# 2022-02-03  0.409048  0.375090
# 2022-02-04  0.378226  0.385072

# %%
# splitting the data into train and test set
# Select 75 % for train and 25 % for test
training_size = round(len(df) * 0.75)

# %%
training_size
# Out:
# 757

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((757, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((707, 50, 2), (707, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# # CREATING LSTM MODEL

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=25, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=25))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # imported Sequential from keras.models
# ----> 2 model = Sequential()
#       3 # importing Dense, Dropout, LSTM, Bidirectional from keras.layers
#       4 model.add(LSTM(units=25, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))
#
# NameError: name 'Sequential' is not defined

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # fitting the model by iterating the dataset over 100 times(100 epochs)
# ----> 2 model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
#
# NameError: name 'model' is not defined

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # predicting the values after running the model
# ----> 2 test_predicted = model.predict(test_seq)
#       3 test_predicted[:5]
#
# NameError: name 'model' is not defined

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Inversing normalization/scaling on predicted data
# ----> 2 test_inverse_predicted = MMS.inverse_transform(test_predicted)
#       3 test_inverse_predicted[:5]
#
# NameError: name 'test_predicted' is not defined

# %% [markdown]
# # VISUALIZING ACTUAL DATA VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df1 = pd.concat([df.iloc[-202:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-202:].index)], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Merging actual and predicted data for better visualization
#       2 df1 = pd.concat([df.iloc[-202:].copy(),
# ----> 3                           pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
#       4                                        index=df.iloc[-202:].index)], axis=1)
#
# NameError: name 'test_inverse_predicted' is not defined

# %%
# Inversing normalization/scaling 
df1[['Open','Close']] = MMS.inverse_transform(df1[['Open','Close']])
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Inversing normalization/scaling
# ----> 2 df1[['Open','Close']] = MMS.inverse_transform(df1[['Open','Close']])
#       3 df1.head()
#
# NameError: name 'df1' is not defined

# %%
# plotting the actual open and predicted open prices on date index
df1[['Open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # plotting the actual open and predicted open prices on date index
# ----> 2 df1[['Open','open_predicted']].plot(figsize=(10,6))
#       3 plt.xticks(rotation=45)
#       4 plt.xlabel('Date',size=15)
#
# NameError: name 'df1' is not defined

# %%
# plotting the actual close and predicted close prices on date index 
df1[['Close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # plotting the actual close and predicted close prices on date index
# ----> 2 df1[['Close','close_predicted']].plot(figsize=(10,6))
#       3 plt.xticks(rotation=45)
#       4 plt.xlabel('Date',size=15)
#
# NameError: name 'df1' is not defined

# %% [markdown]
# # Predicting forthcoming prediction

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
# Creating a dataframe and adding 10 days to existing index 

df2 = pd.concat([df1,pd.DataFrame(columns=df1.columns,
                                        index=pd.date_range(start=df1.index[-1], periods=11, freq='D'))],axis=0)
df2['2022-02-03':'2022-02-21']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Creating a dataframe and adding 10 days to existing index
# ----> 3 df2 = pd.concat([df1,pd.DataFrame(columns=df1.columns,
#       4                                         index=pd.date_range(start=df1.index[-1], periods=11, freq='D'))],axis=0)
#       5 df2['2022-02-03':'2022-02-21']
#
# NameError: name 'df1' is not defined

# %%
# creating a DataFrame and filling values of open and close column
forthcoming_prediction = pd.DataFrame(columns=['open','close'],index=df1.index)
forthcoming_prediction.index=pd.to_datetime(forthcoming_prediction.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # creating a DataFrame and filling values of open and close column
# ----> 2 forthcoming_prediction = pd.DataFrame(columns=['open','close'],index=df1.index)
#       3 forthcoming_prediction.index=pd.to_datetime(forthcoming_prediction.index)
#
# NameError: name 'df1' is not defined

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  forthcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 curr_seq = test_seq[-1:]
#       3 for i in range(-10,0):
# ----> 4   up_pred = model.predict(curr_seq)
#       5   forthcoming_prediction.iloc[i] = up_pred
#       6   curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
#
# NameError: name 'model' is not defined

# %%
# inversing Normalization/scaling
forthcoming_prediction[['open','close']] = MMS.inverse_transform(forthcoming_prediction[['open','close']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # inversing Normalization/scaling
# ----> 2 forthcoming_prediction[['open','close']] = MMS.inverse_transform(forthcoming_prediction[['open','close']])
#
# NameError: name 'forthcoming_prediction' is not defined

# %%
# plotting forthcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Open'],label='Current Open Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('forthcoming Open price prediction',size=15)
ax.legend()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 # plotting forthcoming Open price on date index
#       2 fig,ax=plt.subplots(figsize=(10,5))
# ----> 3 ax.plot(df1.loc['2022-01-24':,'Open'],label='Current Open Price')
#       4 ax.plot(forthcoming_prediction.loc['2022-01-24':,'open'],label='Upcoming Open Price')
#       5 plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
#
# NameError: name 'df1' is not defined

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Close'],label='Current close Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('forthcoming close price prediction',size=15)
ax.legend()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # plotting Upcoming Open price on date index
#       2 fig,ax=plt.subplots(figsize=(10,5))
# ----> 3 ax.plot(df1.loc['2022-01-24':,'Close'],label='Current close Price')
#       4 ax.plot(forthcoming_prediction.loc['2022-01-24':,'close'],label='Upcoming close Price')
#       5 plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
#
# NameError: name 'df1' is not defined
